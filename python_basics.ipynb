# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
Food=input(str("cheeseburger or Big Mac:"))
if Food=="cheeseburger":
    print("The price will be RM 11.90 ")
if Food=="Big Mac":
    print("The price will be RM 15.90 ")
# Out:
# cheeseburger or Big Mac:Big Mac
# The price will be RM 15.90
